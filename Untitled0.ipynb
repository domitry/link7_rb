# %%
require_relative './sim'
# Out:
# "<script>if(window['d3'] === undefined){\n    require.config({paths: {\n\t    d3: 'http://cdnjs.cloudflare.com/ajax/libs/d3/3.4.4/d3.min'\n    }});\n}\n</script>"
# true

# %%
sim = SimWidget.new([ 3*Math::PI/2,0,1.05,-1.04330218,1.15610381 ,-0.18525225, -1.25706716,  0.34137921 ,-0.11993426, 0 , 0 , 0, -0.8653484,0.05947736, -2.66787512, -0.03768383 ,-1.60226281,  1.68681628])
# Out:
# #<SimWidget:0xb9683738 @t=0, @q=[4.71238898038469, 0, 1.05, -1.04330218, 1.15610381, -0.18525225, -1.25706716, 0.34137921, -0.11993426, 0, 0, 0, -0.8653484, 0.05947736, -2.66787512, -0.03768383, -1.60226281, 1.68681628], @dt=0.03, @uuid="bc2b77bb-9d6d-4a6f-b86e-ec2562f9604a", @proc=#<Proc:0xb968301c@/home/domitry/link7_rb/sim.rb:39>, @n_buffer=300>

# %%
sim.run
# Out:
# "<div><svg></svg></div><script>require([\"d3\", \"widgets/js/widget\"], function(d3, WidgetManager){\n\n    var id = function(name){\n        return name + \"bc2b77bb-9d6d-4a6f-b86e-ec2562f9604a\";\n    };\n\n    var init_svg = function(svg){\n        svg.attr(\"id\", id(\"viz\")).style({\n            position: 'relative',\n            width: 400,\n            height: 400\n        });\n\n        for(var i=0;i<=3;i++){\n            [\"L\", \"R\"].forEach(function(lr){\n                svg.append(\"line\").attr({\"id\": id(\"L\" + i + lr), \"class\": \"bone\"});\n            });\n        }\n        svg.append(\"line\").attr({\"id\": id(\"L4\"), \"class\": \"bone\"});\n        svg.append(\"line\").attr({\"id\": id(\"GND\"), \"class\": \"bone\"});\n        svg.selectAll(\"line\").attr({\n            'stroke': \"rgb(0,0,0)\",\n            'stroke-width': 3\n        });\n    };\n\n    // q: [theta, x, y, zeta1, zeta2, zeta3, zeta4, zeta5, zeta6]\n    var draw = function(q){\n        var L1
# ...

# %%
sim.wid
# Out:
# #<IRuby::Widget:0xb95486fc @model_id="190178B6529AA65897D4B164FE06CE68", @comm=#<IRuby::Comm:0xb954860c @comm_id="190178B6529AA65897D4B164FE06CE68", @target_name="WidgetModel", @session=#<IRuby::Session:0xb9716880 @username="kernel", @session="4f7bc26c-5008-4867-9c74-6a4e7a189551", @msg_id=25, @hmac=5c10132b596744c571317c59a419d34b214888d14c5481358439507fe104c2f3, @last_received_header={"username"=>"username", "msg_id"=>"FD9E5A22409749BA8E29430D81861B39", "msg_type"=>"execute_request", "session"=>"64E19E0A391A480CA42F6B485640EB1E"}>, @iopub_socket=#<ZMQ::Socket:0xb97169fc @receiver_klass=ZMQ::Message, @socket=#<FFI::Pointer address=0xb98b8f50>, @name="PUB", @int_cache=nil, @longlong_cache=nil, @more_parts_array=[], @option_lookup=[nil, nil, nil, nil, 1, 2, 2, 2, 0, 0, nil, 0, 0, 1, 0, 0, 0, 0, 0, 0, nil, 0, 1, 0, 0, 0, nil, 0, 0, nil, nil, 0, 2, 0, 0, 0, 0, 0, 0, 0, nil, nil, 0, 0, 0, 2, 2, 0, 2, 2, 2, 0, 0, 0, 0, 2]>>>

# %%
require 'iruby'
require 'securerandom'
# Out:
# false

# %%
comm = IRuby::Comm.new("WidgetModel", SecureRandom.hex(16))
# Out:
# #<IRuby::Comm:0xb8741874 @comm_id="bd0313b921f25a340351f9068197b110", @target_name="WidgetModel", @session=#<IRuby::Session:0xb8a1a3d4 @username="kernel", @session="2ca05d05-73c2-40b1-ae4f-47c1dc0b23a4", @msg_id=24, @hmac=fa06453441934810a9cc3cae02fd65c076dc826fcb326174796298f4b143f77d, @last_received_header={"username"=>"username", "msg_id"=>"36345F3663B94487AA3F67237756337B", "msg_type"=>"execute_request", "session"=>"61E8BE895F7E4BDF906CEFE543067B2A"}>, @iopub_socket=#<ZMQ::Socket:0xb8a1a550 @receiver_klass=ZMQ::Message, @socket=#<FFI::Pointer address=0xb8bc2110>, @name="PUB", @int_cache=nil, @longlong_cache=nil, @more_parts_array=[], @option_lookup=[nil, nil, nil, nil, 1, 2, 2, 2, 0, 0, nil, 0, 0, 1, 0, 0, 0, 0, 0, 0, nil, 0, 1, 0, 0, 0, nil, 0, 0, nil, nil, 0, 2, 0, 0, 0, 0, 0, 0, 0, nil, nil, 0, 0, 0, 2, 2, 0, 2, 2, 2, 0, 0, 0, 0, 2]>, @ident="ab8b419cd7cc64e155b72d51e4a9b419">

# %%
comm.open({})
# Out:
# ["<IDS|MSG>", "61eb5030153fb96fe98e98b291da1cbb8b983192d80a5e6ba9cb3159f8be819f", "{\"msg_type\":\"comm_open\",\"msg_id\":28,\"username\":\"kernel\",\"session\":\"2ca05d05-73c2-40b1-ae4f-47c1dc0b23a4\"}", "{\"username\":\"username\",\"msg_id\":\"498436BBECD24EC2866629A30C2C30E2\",\"msg_type\":\"execute_request\",\"session\":\"61E8BE895F7E4BDF906CEFE543067B2A\"}", "{}", "{\"comm_id\":\"1e40b4e341511c0e71103e15a79d7bb0\",\"data\":{},\"target_name\":\"WidgetModel\"}"]
